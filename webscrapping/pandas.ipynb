# %%
import pandas as pd

# Importar o arquivo CSV
df = pd.read_csv('../databases/scratch-projects.csv')

# Imprima o DataFrame
df.head(10)
# Out:
#           id           author  \
# 0  258848998     AsterixDavid
# 1  707277450  Debility_Kheops
# 2  792610240  Switch4FortNite
# 3  795072056        Ricky-Jan
# 4  707652608       covcheg008
# 5  775596408     Thebenjiball
# 6  777112739         chipm0nk
# 7  670212530     PLAYtntGAMER
# 8  789694494        theCharpy
# 9  783760319         Riddle_5
#
#                                                title  \
# 0  Agent One || Mobile Scrolling Adventure || #ga...
# 1                                     Rocket Sky 1.5
# 2  -DOORS A PLATFORMER- V2.0 #trending #all #game...
# 3                                 Scratchy Adventure
# 4                                TROLLING platformer
# 5                                           MOONWALK
# 6                    Elf Quest | A Platformer #Games
# 7                            Fill The Gap Platformer
# 8  Ball Clicker v1.5.1 || #all #games #art #music...
# 9                                      Pixel Fighter
#
# ...

# %%
df.notna().sum()
# Out:
# id              8830
# author          8734
# title           8732
# description     6888
# instructions    7827
# public          8830
# image           8734
# views           8830
# loves           8830
# favorites       8830
# remixes         8830
# token           8734
# created_at      8734
# modified_at     8734
# shared_at       8734
# total_blocks    8830
# n_events        8830
# n_looks         8830
# n_sounds        8830
# n_controls      8830
# n_pens          8830
# n_procedures    8830
# n_motions       8830
# n_datas         8830
# n_operators     8830
# n_sensings      8830
# n_arguments     8830
# dtype: int64

# %%
df.shape
# Out:
# (8830, 27)

# %%
# dropar as linhas com author vazio
df_new = df.dropna(subset=['author'])
df_new = df_new.dropna(subset=['title'])

# %%
df_new.shape
# Out:
# (8732, 27)

# %%
df_new.to_csv('../databases/scratch-projects.csv', index=False)

# %%
df_new.notna().sum()
# Out:
# id              8732
# author          8732
# title           8732
# description     6888
# instructions    7827
# public          8732
# image           8732
# views           8732
# loves           8732
# favorites       8732
# remixes         8732
# token           8732
# created_at      8732
# modified_at     8732
# shared_at       8732
# total_blocks    8732
# n_events        8732
# n_looks         8732
# n_sounds        8732
# n_controls      8732
# n_pens          8732
# n_procedures    8732
# n_motions       8732
# n_datas         8732
# n_operators     8732
# n_sensings      8732
# n_arguments     8732
# dtype: int64
